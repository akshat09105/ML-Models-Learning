# %% [markdown]
# <a href="https://colab.research.google.com/github/akshat09105/ML_Learning_models/blob/main/Clustering_my_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --force-reinstall --no-cache-dir numpy==1.26.4 scipy==1.11.4 pandas==1.5.3 matplotlib==3.2.2

# This installation will ask for Restart the session; Click on "Restart Session"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 164.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 MB 123.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 102.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 92.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 95.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 108.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 175.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 238.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 297.4 MB/s eta 0:00:00
# ...

# %%
# !pip install pycaret &> /dev/null

# %%
from pycaret.utils import version
version()
# Out:
# '3.3.2'

# %% [markdown]
# 1. Clustering - Part 1 (Kmean Clustering)

# %% [markdown]
# 1.1 Get the list of datasets available in pycaret (56)

# %%
from pycaret.datasets import get_data
get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %% [markdown]
# 1.2 Get the "jewellery" dataset

# %%
mydataset=get_data('jewellery')
mydataset
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130
#      Age  Income  SpendingScore       Savings
# 0     58   77769       0.791329   6559.829923
# 1     59   81799       0.791082   5417.661426
# 2     62   74751       0.702657   9258.992965
# 3     59   74373       0.765680   7346.334504
# 4     87   17760       0.348778  16869.507130
# ..   ...     ...            ...           ...
# 500   28  101206       0.387441  14936.775389
# 501   93   19934       0.203140  17969.693769
# 502   90   35297       0.355149  16091.401954
# 503   91   20681       0.354679  18401.088445
# 504   89   30267       0.289310  14386.351880
#
# [505 rows x 4 columns]

# %% [markdown]
# 1.3 Save and Download the dataset to local system

# %%
mydataset.to_csv("jewellery.csv")

# %% [markdown]
# 1.4 "Parameter setting" for clustering model

# %%
from pycaret.clustering import *
setup(data=mydataset)
# Out:
# <style type="text/css">
# #T_b6092_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b6092" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6092_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b6092_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6092_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6092_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b6092_row0_col1" class="data row0 col1" >2019</td>
#     </tr>
#     <tr>
#       <th id="T_b6092_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6092_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_b6092_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Creating Kmean clustering Model

# %%
kmeansclusterModel=create_model("kmeans",num_clusters=3)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5d647" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d647_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5d647_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5d647_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5d647_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5d647_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5d647_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d647_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d647_row0_col0" class="data row0 col0" >0.7393</td>
#       <td id="T_5d647_row0_col1" class="data row0 col1" >3567.5370</td>
# ...

# %% [markdown]
# 1.6 Assign Model - "Assign the labels" to the dataset

# %%
kmeanprediction=assign_model(kmeansclusterModel)
kmeanprediction
# Out:
#      Age  Income  SpendingScore       Savings    Cluster
# 0     58   77769       0.791329   6559.830078  Cluster 2
# 1     59   81799       0.791082   5417.661621  Cluster 2
# 2     62   74751       0.702657   9258.993164  Cluster 2
# 3     59   74373       0.765680   7346.334473  Cluster 2
# 4     87   17760       0.348778  16869.507812  Cluster 1
# ..   ...     ...            ...           ...        ...
# 500   28  101206       0.387441  14936.775391  Cluster 0
# 501   93   19934       0.203140  17969.693359  Cluster 1
# 502   90   35297       0.355149  16091.402344  Cluster 1
# 503   91   20681       0.354679  18401.087891  Cluster 1
# 504   89   30267       0.289310  14386.351562  Cluster 1
#
# [505 rows x 5 columns]

# %% [markdown]
# 1.7 Three line code

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
mydataset=get_data("jewellery")
setup(data=mydataset)
kmeansClusteringModel=create_model("kmeans",num_clusters=3)
kmeanspredictions=predict_model(kmeansClusteringModel,data=mydataset.iloc[:10])
kmeanspredictions
# Out:
#    Unnamed: 0  Age  Income  SpendingScore       Savings
# 0           0   58   77769       0.791329   6559.829923
# 1           1   59   81799       0.791082   5417.661426
# 2           2   62   74751       0.702657   9258.992965
# 3           3   59   74373       0.765680   7346.334504
# 4           4   87   17760       0.348778  16869.507130
# <style type="text/css">
# #T_22f19_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_22f19" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22f19_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_22f19_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22f19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22f19_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_22f19_row0_col1" class="data row0 col1" >1521</td>
# ...

# %% [markdown]
# 1.8 Downloading predictions

# %%
kmeanspredictions.to_csv("predictions.csv")

# %% [markdown]
# 2. Clustering: Save, Upload and Load the Model

# %% [markdown]
# 2.1 Save the "trained model"

# %%
sm=save_model(kmeansClusteringModel,"kmeansClusteringModel")
# Out:
# Transformation Pipeline and Model Successfully Saved

# %% [markdown]
# 2.2 Load the model

# %%
kmeansClusteringModel=load_model("kmeansClusteringModel")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# 3. Clustering: Cluster the new dataset (Unseen Data)

# %% [markdown]
# 3.1 Select some data or upload user dataset file

# %%
newdataset=mydataset.iloc[:10]

# %% [markdown]
# 3.2 Make prediction on the new dataset (Unseen Data)

# %%
predictions=predict_model(kmeansClusteringModel,data=mydataset)
predictions
# Out:
#      Unnamed: 0  Age  Income  SpendingScore       Savings    Cluster
# 0             0   58   77769       0.791329   6559.830078  Cluster 0
# 1             1   59   81799       0.791082   5417.661621  Cluster 0
# 2             2   62   74751       0.702657   9258.993164  Cluster 0
# 3             3   59   74373       0.765680   7346.334473  Cluster 0
# 4             4   87   17760       0.348778  16869.507812  Cluster 1
# ..          ...  ...     ...            ...           ...        ...
# 500         500   28  101206       0.387441  14936.775391  Cluster 2
# 501         501   93   19934       0.203140  17969.693359  Cluster 1
# 502         502   90   35297       0.355149  16091.402344  Cluster 1
# 503         503   91   20681       0.354679  18401.087891  Cluster 1
# 504         504   89   30267       0.289310  14386.351562  Cluster 1
#
# [505 rows x 6 columns]

# %% [markdown]
# 3.3 Save the prediction result to csv

# %%
predictions.to_csv("newpredictions.csv")

# %% [markdown]
# **4. Clustering: Ploting the Cluster**
#
# ---
# Following plots can be generated for *clusters*
# 1. Cluster PCA Plot (2d)          'cluster'
# 2. Cluster TSnE (3d)              'tsne'
# 3. Elbow Plot                     'elbow'
# 4. Silhouette Plot                'silhouette'
# 5. Distance Plot                  'distance'
# 6. Distribution Plot              'distribution'

# %% [markdown]
# 4.1 Evaluate Cluster Model

# %%
evaluate_model(kmeansClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# 4.2 2D-plot for Cluster

# %%
plot_model(kmeansClusteringModel,plot='cluster')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 4.3 3D-plot for Clustering

# %%
plot_model(kmeansClusteringModel,plot='tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 4.4 2D-plot for elbow plot

# %%
plot_model(kmeansClusteringModel,"elbow")

# %% [markdown]
# 4.5 plot for silhouette plot

# %%
plot_model(kmeansClusteringModel,"silhouette")

# %% [markdown]
# 4.6 for Distance plot

# %%
plot_model(kmeansClusteringModel,"distance")

# %% [markdown]
# 4.7 plot for distribution plot

# %%
plot_model(kmeansClusteringModel,"distribution")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 5. Compelete Code for Clustering (KMean)

# %% [markdown]
# 5.1 For Cluster = 3, 4, 5, 6

# %%
for i in range(3,7):
  print(f"for no of clusters={i}")
  setup(data=mydataset,verbose=False)
  kmeansclusteringModel=create_model("kmeans",num_clusters=i)
# Out:
# for no of clusters=3
# <style type="text/css">
# </style>
# <table id="T_b9f56" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9f56_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b9f56_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b9f56_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b9f56_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b9f56_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b9f56_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9f56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9f56_row0_col0" class="data row0 col0" >0.7392</td>
#       <td id="T_b9f56_row0_col1" class="data row0 col1" >3566.6682</td>
# ...

# %% [markdown]
# 5.2 Other Clustering Algorithms

# %% [markdown]
# 1. K-Means clustering                 'kmeans'
# 2. Affinity Propagation               'ap'
# 3. Mean shift clustering              'meanshift'
# 4. Spectral Clustering                'sc'
# 5. Agglomerative Clustering           'hclust'
# 6. Density-Based Spatial Clustering   'dbscan'
# 7. OPTICS Clustering                  'optics'
# 8. Birch Clustering                   'birch'
# 9. K-Modes clustering                 'kmodes'

# %% [markdown]
# 6. Clustering: Apply "Data Preprocessing"
#
# ---
# Read the Dataset

# %% [markdown]
# 6.1 Model Performance using "Normalization"

# %% [markdown]
# 6.1.1 Elbow Plot

# %%
setup(data = mydataset, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans', verbose=False)
plot_model(x, plot = 'elbow')

# %% [markdown]
# 6.1.2 Evaluation parameters for Cluster = 3, 4, 5, 6

# %%
for i in range(3,7):
  print(f"for number of cluster={i}")
  setup(data=mydataset,normalize=True,normalize_method="zscore",verbose=False)
  kmeansClusteringModel=create_model("kmeans",num_clusters=i)
# Out:
# for number of cluster=3
# <style type="text/css">
# </style>
# <table id="T_5ca90" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ca90_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5ca90_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5ca90_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5ca90_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5ca90_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5ca90_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ca90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ca90_row0_col0" class="data row0 col0" >0.3591</td>
#       <td id="T_5ca90_row0_col1" class="data row0 col1" >240.1974</td>
# ...

# %% [markdown]
# 6.1.3 3D Plot for Cluster = 3 (Most important and interesting step)

# %%
setup(data=mydataset,normalize=True,verbose=False)
kmeansClusteringModel=create_model("kmeans",num_clusters=3)
plot_model(kmeansClusteringModel,"tsne")
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ef25" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ef25_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9ef25_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9ef25_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9ef25_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9ef25_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9ef25_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ef25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ef25_row0_col0" class="data row0 col0" >0.5089</td>
#       <td id="T_9ef25_row0_col1" class="data row0 col1" >464.6299</td>
# ...

# %% [markdown]
# 6.2 Model Performance using "Transformation" + "Normalization" + "PCA"

# %% [markdown]
# 6.5.1 Elbow Plot

# %%
setup(data=mydataset,normalize=True,normalize_method="zscore",transformation=True,transformation_method="yeo-johnson",pca=True,pca_method="linear",verbose=False)
kmeansClusteringModel=create_model("kmeans")
plot_model(kmeansClusteringModel,plot="elbow")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7689a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7689a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7689a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7689a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7689a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7689a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7689a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7689a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7689a_row0_col0" class="data row0 col0" >0.4637</td>
#       <td id="T_7689a_row0_col1" class="data row0 col1" >365.7818</td>
# ...

# %% [markdown]
# 6.5.2 Evaluation parameters for Cluster = 3, 4, 5, 6

# %%
for i in range(3,7):
  print(f"for number of clusters={i}")
  setup(data=mydataset,normalize=True,normalize_method="zscore",transformation=True,transformation_method="yeo-johnson",pca=True,pca_method="linear",verbose=False)
  kmeansClusteringModel=create_model("kmeans",num_clusters=i)
# Out:
# for number of clusters=3
# <style type="text/css">
# </style>
# <table id="T_a58e3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a58e3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a58e3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a58e3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a58e3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a58e3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a58e3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a58e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a58e3_row0_col0" class="data row0 col0" >0.5079</td>
#       <td id="T_a58e3_row0_col1" class="data row0 col1" >452.5580</td>
# ...

# %% [markdown]
# therefore PLot 3D model for n=4

# %%
plot_model(kmeansClusteringModel,plot="tsne")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 7. Other Clustering Techniques

# %% [markdown]
# 7.1 Buildign Agglomerative (Hierarchical) clustering model

# %%
from pycaret.clustering import *
from pycaret.datasets import get_data
mydataset=get_data("jewellery")
setup(data=mydataset)
hclustModel=create_model("hclust")
plot_model(hclustModel,plot="elbow")
# Out:
#    Unnamed: 0  Age  Income  SpendingScore       Savings
# 0           0   58   77769       0.791329   6559.829923
# 1           1   59   81799       0.791082   5417.661426
# 2           2   62   74751       0.702657   9258.992965
# 3           3   59   74373       0.765680   7346.334504
# 4           4   87   17760       0.348778  16869.507130
# <style type="text/css">
# #T_d5e43_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d5e43" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5e43_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d5e43_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5e43_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5e43_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d5e43_row0_col1" class="data row0 col1" >357</td>
# ...

# %% [markdown]
# ---
# ### **7.1.1 Assign Model - "Assign the labels" to the dataset**
# ---

# %%
hierarchialpredictions=assign_model(hclustModel)
hierarchialpredictions
# Out:
#      Unnamed: 0  Age  Income  SpendingScore       Savings    Cluster
# 0             0   58   77769       0.791329   6559.830078  Cluster 2
# 1             1   59   81799       0.791082   5417.661621  Cluster 2
# 2             2   62   74751       0.702657   9258.993164  Cluster 2
# 3             3   59   74373       0.765680   7346.334473  Cluster 2
# 4             4   87   17760       0.348778  16869.507812  Cluster 1
# ..          ...  ...     ...            ...           ...        ...
# 500         500   28  101206       0.387441  14936.775391  Cluster 3
# 501         501   93   19934       0.203140  17969.693359  Cluster 1
# 502         502   90   35297       0.355149  16091.402344  Cluster 1
# 503         503   91   20681       0.354679  18401.087891  Cluster 1
# 504         504   89   30267       0.289310  14386.351562  Cluster 1
#
# [505 rows x 6 columns]

# %% [markdown]
# Key Points

# %% [markdown]
# num_clusters not required for some of the clustering Alorithms (Affinity Propagation ('ap'), Mean shift clustering ('meanshift'), Density-Based Spatial Clustering ('dbscan') and OPTICS Clustering ('optics')).
#
# num_clusters param for these models are automatically determined.
#
# When fit doesn't converge in Affinity Propagation ('ap') model, all datapoints are labelled as -1.
#
# Noisy samples are given the label -1, when using Density-Based Spatial ('dbscan') or OPTICS Clustering ('optics').
#
# OPTICS ('optics') clustering may take longer training times on large datasets.
